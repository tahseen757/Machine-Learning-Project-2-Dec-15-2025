# %%
import requests
import time
import csv
import os
import json

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from imdb import IMDb

# %%
TMDB_API_KEY = '2762321c463faabbba42b561409706aa'  # Replace this with your actual TMDB API key
WIKI_URL = "https://en.wikipedia.org/wiki/List_of_highest-grossing_films"

# %%
# Module 1: Fetch basic movie list from Wikipedia
# This function scrapes Wikipedia to get a list of top highest-grossing films.
# It returns a DataFrame with columns: Rank, Title, Worldwide_Gross, Year, Wiki_Link
def fetch_highest_grossing_films(num_movies=50):
    """
    Scrape the list of highest-grossing films from Wikipedia.

    This function:
    1. Sends a request to the Wikipedia URL.
    2. Parses the HTML to find the table of highest-grossing films.
    3. Extracts data from the table rows (skipping the header).
    4. Limits the results to the specified number of movies.

    Args:
        num_movies (int): How many top movies to fetch (default is 50 to avoid too many requests).

    Returns:
        pd.DataFrame: A table with basic movie info.
    """
    # Send HTTP request to Wikipedia
    url = WIKI_URL
    response = requests.get(url)
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the specific table on the page (it's the first 'wikitable sortable')
    table = soup.find('table', {'class': 'wikitable sortable'})
    # Get all rows in the table
    rows = table.find_all('tr')

    # List to store movie data
    data = []
    # Loop through rows starting from index 1 (skip header) up to num_movies + 1
    for row in rows[1:num_movies+1]:
        # Get all columns (td tags) in the row
        cols = row.find_all('td')
        if len(cols) >= 4:  # Ensure it's a valid row with at least 4 columns
            rank = cols[0].text.strip()  # Clean text: remove extra spaces
            title = cols[1].text.strip()
            gross = cols[2].text.strip().replace('$', '').replace(',', '')  # Remove $ and commas for numeric value
            year = cols[3].text.strip()
            # Get the Wikipedia link if available
            link = "https://en.wikipedia.org" + cols[1].find('a')['href'] if cols[1].find('a') else None
            # Add to data list as a dictionary
            data.append({
                'Rank': rank,
                'Title': title,
                'Worldwide_Gross': gross,
                'Year': year,
                'Wiki_Link': link
            })

    # Convert list of dicts to a pandas DataFrame
    return pd.DataFrame(data)

    #this was later discarded due to data not being parsed from wikipedia.

# %%
# --- Exploratory TMDB fetch (not used in final pipeline) ---
# def fetch_tmdb_test_version_1():


# Module 2: Fetch details from TMDB for a single movie
# This function queries TMDB API for one movie's details using title and year.
def fetch_tmdb_details(title, year):
    """
    Fetch movie details from TMDB API for a single movie.

    This function:
    1. Searches TMDB for the movie by title and year.
    2. If found, gets the movie ID.
    3. Fetches detailed info including credits (cast and crew).
    4. Extracts features like genre, director, actors, etc.

    Args:
        title (str): Movie title.
        year (str): Release year.

    Returns:
        dict: A dictionary with TMDB features (or 'N/A' if not found).
    """
    # Default dictionary with 'N/A' values
    movie_data = {
        'Genre': 'N/A',
        'Director': 'N/A',
        'Actors': 'N/A',
        'Release_Date': 'N/A',
        'Runtime': 'N/A',
        'Budget': 'N/A',
        'Revenue': 'N/A',
        'Vote_Average': 'N/A'
    }

    try:
        # Construct search URL with API key, title, and year
        search_url = f"https://api.themoviedb.org/3/search/movie?api_key={TMDB_API_KEY}&query={title}&year={year}"
        # Get response and parse as JSON
        search_response = requests.get(search_url).json()

        # If search results exist
        if search_response['results']:
            # Take the first result's ID (most relevant)
            movie_id = search_response['results'][0]['id']
            # Construct details URL with credits appended
            details_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={TMDB_API_KEY}&append_to_response=credits"
            details_response = requests.get(details_url).json()

            # Extract genres as comma-separated string
            movie_data['Genre'] = ', '.join([genre['name'] for genre in details_response.get('genres', [])])

            # Find director from crew list
            director = next((member['name'] for member in details_response['credits'].get('crew', []) if member['job'] == 'Director'), 'N/A')
            movie_data['Director'] = director

            # Get top 5 actors from cast
            actors = details_response['credits'].get('cast', [])[:5]
            movie_data['Actors'] = ', '.join([actor['name'] for actor in actors])

            # Other details
            movie_data['Release_Date'] = details_response.get('release_date', 'N/A')
            movie_data['Runtime'] = details_response.get('runtime', 'N/A')
            movie_data['Budget'] = details_response.get('budget', 'N/A')
            movie_data['Revenue'] = details_response.get('revenue', 'N/A')
            movie_data['Vote_Average'] = details_response.get('vote_average', 'N/A')

        # Delay to avoid hitting API rate limits
        time.sleep(1)
        return movie_data
    except Exception as e:
        # Print error if something goes wrong
        print(f"Error with TMDB for {title}: {e}")
        return movie_data

# This function applies fetch_tmdb_details to all rows in a DataFrame
def enhance_with_tmdb(df):
    """
    Enhance the entire DataFrame with TMDB details.

    This loops through each row, fetches TMDB data, and adds it to the DataFrame.

    Args:
        df (pd.DataFrame): Input DataFrame with 'Title' and 'Year'.

    Returns:
        pd.DataFrame: DataFrame with added TMDB columns.
    """
    # List to store TMDB data for each movie
    tmdb_data = []
    # Iterate over each row in the DataFrame
    for _, row in df.iterrows():
        details = fetch_tmdb_details(row['Title'], row['Year'])
        tmdb_data.append(details)

    # Convert list to DataFrame and concatenate horizontally
    tmdb_df = pd.DataFrame(tmdb_data)
    return pd.concat([df, tmdb_df], axis=1)

# %%
# --- Exploratory TMDB fetch (not used in final pipeline) ---
# def fetch_tmdb_test_version_2():

# Import necessary libraries
# - requests: For making HTTP requests to APIs
# - pandas: For handling data in DataFrames (like tables)
# - time: For adding delays to avoid overwhelming servers
# - IMDb: From imdbpy library, for accessing IMDB data (install with pip install imdbpy) - optional
import requests
import pandas as pd
import time
from imdb import IMDb

# Configuration settings
# - TMDB_API_KEY: Provided TMDB API key
TMDB_API_KEY = '2762321c463faabbba42b561409706aa'

# Module 1: Fetch top movies from TMDB (sorted by revenue.desc)
# This function uses TMDB's discover/movie endpoint to get top-grossing films.
# It returns a DataFrame with columns: Title, Year, TMDB_ID
def fetch_top_movies_from_tmdb(num_movies=50, min_year=None):
    """
    Fetch top-grossing movies from TMDB using discover/movie sorted by revenue.desc.

    This function:
    1. Constructs the API URL with sort_by=revenue.desc and pagination.
    2. Optionally filters by minimum year (e.g., primary_release_year.gte=2010).
    3. Extracts title, year (from release_date), and ID for each movie.
    4. Stops once num_movies is reached.

    Args:
        num_movies (int): How many top movies to fetch (default 50).
        min_year (int): Optional minimum release year (e.g., 2010 for recent data).

    Returns:
        pd.DataFrame: A table with basic movie info (Title, Year, TMDB_ID).
    """
    movies = []
    page = 1
    while len(movies) < num_movies:
        # Construct URL with sort_by=revenue.desc
        url = f"https://api.themoviedb.org/3/discover/movie?api_key={TMDB_API_KEY}&sort_by=revenue.desc&page={page}"
        if min_year:
            url += f"&primary_release_year.gte={min_year}"  # Filter for recent years if specified
        response = requests.get(url).json()

        if 'results' not in response or not response['results']:
            break  # No more results

        for movie in response['results']:
            year = movie.get('release_date', '')[:4]  # Extract year from release_date
            if year:  # Skip if no release date
                movies.append({
                    'Title': movie['title'],
                    'Year': year,
                    'TMDB_ID': movie['id']
                })
            if len(movies) >= num_movies:
                break

        page += 1
        time.sleep(1)  # Delay to avoid rate limits

    if not movies:
        print("No movies fetched from TMDB. Check API key or parameters.")
        return pd.DataFrame()

    return pd.DataFrame(movies)

# Module 2: Fetch details from TMDB for a single movie using ID
# This function queries TMDB's movie/{id} endpoint for details.
def fetch_tmdb_details(movie_id):
    """
    Fetch movie details from TMDB API for a single movie using its ID.

    This function:
    1. Fetches detailed info including credits (cast and crew).
    2. Extracts features like genre, director, actors, release_date, runtime, budget, revenue (as Worldwide_Gross), vote_average.

    Args:
        movie_id (int): TMDB movie ID.

    Returns:
        dict: A dictionary with TMDB features (or 'N/A' if not found).
    """
    # Default dictionary with 'N/A' values
    movie_data = {
        'Genre': 'N/A',
        'Director': 'N/A',
        'Actors': 'N/A',
        'Release_Date': 'N/A',
        'Runtime': 'N/A',
        'Budget': 'N/A',
        'Worldwide_Gross': 'N/A',  # Use revenue as gross
        'Vote_Average': 'N/A'
    }

    try:
        # Construct details URL with credits appended
        details_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={TMDB_API_KEY}&append_to_response=credits"
        details_response = requests.get(details_url).json()

        if 'status_code' in details_response and details_response['status_code'] != 200:
            raise Exception(details_response.get('status_message', 'Unknown error'))

        # Extract genres as comma-separated string
        movie_data['Genre'] = ', '.join([genre['name'] for genre in details_response.get('genres', [])])

        # Find director from crew list
        director = next((member['name'] for member in details_response['credits'].get('crew', []) if member['job'] == 'Director'), 'N/A')
        movie_data['Director'] = director

        # Get top 5 actors from cast
        actors = details_response['credits'].get('cast', [])[:5]
        movie_data['Actors'] = ', '.join([actor['name'] for actor in actors])

        # Other details
        movie_data['Release_Date'] = details_response.get('release_date', 'N/A')
        movie_data['Runtime'] = details_response.get('runtime', 'N/A')
        movie_data['Budget'] = details_response.get('budget', 'N/A')
        movie_data['Worldwide_Gross'] = details_response.get('revenue', 'N/A')  # Revenue as gross
        movie_data['Vote_Average'] = details_response.get('vote_average', 'N/A')

        time.sleep(1)  # Delay to avoid hitting API rate limits
        return movie_data
    except Exception as e:
        print(f"Error with TMDB for movie ID {movie_id}: {e}")
        return movie_data

# This function applies fetch_tmdb_details to all rows in a DataFrame using TMDB_ID
def enhance_with_tmdb(df):
    """
    Enhance the entire DataFrame with TMDB details using TMDB_ID.

    This loops through each row, fetches details by ID, and adds them to the DataFrame.

    Args:
        df (pd.DataFrame): Input DataFrame with 'TMDB_ID'.

    Returns:
        pd.DataFrame: DataFrame with added TMDB columns.
    """
    tmdb_data = []
    for _, row in df.iterrows():
        details = fetch_tmdb_details(row['TMDB_ID'])
        tmdb_data.append(details)

    tmdb_df = pd.DataFrame(tmdb_data)
    return pd.concat([df, tmdb_df], axis=1)

# Module 3: Fetch IMDB details for a single movie (optional)
def fetch_imdb_details(title):
    """
    Fetch IMDB details for a single movie.

    This uses the imdbpy library to search IMDB.

    Args:
        title (str): Movie title.

    Returns:
        dict: Dictionary with IMDB rating and votes (or 'N/A').
    """
    try:
        ia = IMDb()
        movies = ia.search_movie(title)
        if movies:
            movie = ia.get_movie(movies[0].movieID)
            return {
                'IMDB_Rating': movie.get('rating', 'N/A'),
                'Votes': movie.get('votes', 'N/A')
            }
        time.sleep(1)
        return {'IMDB_Rating': 'N/A', 'Votes': 'N/A'}
    except Exception as e:
        print(f"Error with IMDB for {title}: {e}")
        return {'IMDB_Rating': 'N/A', 'Votes': 'N/A'}

# This function applies fetch_imdb_details to all rows
def enhance_with_imdb(df):
    """
    Enhance the DataFrame with IMDB details.

    Args:
        df (pd.DataFrame): Input DataFrame with 'Title'.

    Returns:
        pd.DataFrame: DataFrame with added IMDB columns.
    """
    imdb_data = []
    for _, row in df.iterrows():
        details = fetch_imdb_details(row['Title'])
        imdb_data.append(details)

    imdb_df = pd.DataFrame(imdb_data)
    return pd.concat([df, imdb_df], axis=1)

# Module 4: Clean the data
# Converts financial columns to numeric values in millions.
def clean_data(df):
    """
    Clean the DataFrame by converting financials to numbers (in millions).

    This handles:
    - Converting Worldwide_Gross, Budget, and Revenue (if present) to floats divided by 1,000,000.
    - Handles 'N/A' as NaN.

    Args:
        df (pd.DataFrame): Input DataFrame.

    Returns:
        pd.DataFrame: Cleaned DataFrame.
    """
    df['Worldwide_Gross'] = pd.to_numeric(df['Worldwide_Gross'], errors='coerce') / 1000000
    df['Budget'] = pd.to_numeric(df['Budget'], errors='coerce') / 1000000
    return df

# Module 5: Build the full fact table
# This orchestrates everything: fetch top movies, enhance with details, clean, save.
def build_fact_table(num_movies=50, min_year=2010, use_imdb=True):
    """
    Build the complete fact table using only TMDB.

    Steps:
    1. Fetch top movies from TMDB (sorted by revenue.desc, optional min_year filter).
    2. Add TMDB details using movie IDs.
    3. Optionally add IMDB details.
    4. Clean the data.
    5. Save to CSV.

    Args:
        num_movies (int): Number of movies to process.
        min_year (int): Minimum release year (default 2010 for recent data; set to None for all time).
        use_imdb (bool): Whether to include IMDB data (default True).

    Returns:
        pd.DataFrame: The final fact table.
    """
    # Step 1: Get top movies from TMDB
    df = fetch_top_movies_from_tmdb(num_movies, min_year)
    if df.empty:
        return df
    # Step 2: Add TMDB details
    df = enhance_with_tmdb(df)
    # Step 3: Add IMDB if requested
    if use_imdb:
        df = enhance_with_imdb(df)
    # Step 4: Clean
    df = clean_data(df)

    # Save the DataFrame to a CSV file
    df.to_csv('movie_fact_table.csv', index=False)
    print("Fact table saved to movie_fact_table.csv")
    return df

# Run the script when executed directly
# This is the entry point: calls build_fact_table and prints the first few rows
# Adjust min_year as needed (e.g., None for all time, or 2000 for broader data)
if __name__ == "__main__":
    fact_table = build_fact_table(min_year=2010)  # Example: data from 2010 onward
    print(fact_table.head())
# Out:
# Fact table saved to movie_fact_table.csv
#                       Title  Year  TMDB_ID  \
# 0                    Avatar  2009    19995
# 1         Avengers: Endgame  2019   299534
# 2  Avatar: The Way of Water  2022    76600
# 3                   Titanic  1997      597
# 4                  Ne Zha 2  2025   980477
#
#                                          Genre       Director  \
# 0  Action, Adventure, Fantasy, Science Fiction  James Cameron
# 1           Adventure, Science Fiction, Action  Anthony Russo
# 2           Action, Adventure, Science Fiction  James Cameron
# 3                               Drama, Romance  James Cameron
# 4        Animation, Fantasy, Adventure, Action        Jiao Zi
#
#                                               Actors Release_Date  Runtime  \
# 0  Sam Worthington, Zoe Saldaña, Sigourney Weaver...   2009-12-15      162
# 1  Robert Downey Jr., Chris Evans, Mark Ruffalo, ...   2019-04-24      181
# 2  Sam Worthington, Zoe Saldaña, Sigourney Weaver...   2022-12-14      192
# 3  Leonardo DiCaprio, Kate Winslet, Billy Zane, K...   1997-11-18      194
# 4        Lu Yanting, Joseph, Han Mo, Chen Hao, Lu Qi   2025-01-29      144
#
#    Budget  Worldwide_Gross  Vote_Average IMDB_Rating Votes
# 0   237.0      2923.706026         7.594         N/A   N/A
# 1   356.0      2799.439100         8.237         N/A   N/A
# 2   350.0      2353.096253         7.609         N/A   N/A
# 3   200.0      2264.162353         7.903         N/A   N/A
# 4    80.0      2150.000000         8.068         N/A   N/A

# %%
fact_table.head()
# Out:
#                       Title  Year  TMDB_ID  \
# 0                    Avatar  2009    19995
# 1         Avengers: Endgame  2019   299534
# 2  Avatar: The Way of Water  2022    76600
# 3                   Titanic  1997      597
# 4                  Ne Zha 2  2025   980477
#
#                                          Genre       Director  \
# 0  Action, Adventure, Fantasy, Science Fiction  James Cameron
# 1           Adventure, Science Fiction, Action  Anthony Russo
# 2           Action, Adventure, Science Fiction  James Cameron
# 3                               Drama, Romance  James Cameron
# 4        Animation, Fantasy, Adventure, Action        Jiao Zi
#
#                                               Actors Release_Date  Runtime  \
# 0  Sam Worthington, Zoe Saldaña, Sigourney Weaver...   2009-12-15      162
# 1  Robert Downey Jr., Chris Evans, Mark Ruffalo, ...   2019-04-24      181
# 2  Sam Worthington, Zoe Saldaña, Sigourney Weaver...   2022-12-14      192
# 3  Leonardo DiCaprio, Kate Winslet, Billy Zane, K...   1997-11-18      194
# 4        Lu Yanting, Joseph, Han Mo, Chen Hao, Lu Qi   2025-01-29      144
#
#    Budget  Worldwide_Gross  Vote_Average IMDB_Rating Votes
# 0   237.0      2923.706026         7.594         N/A   N/A
# 1   356.0      2799.439100         8.237         N/A   N/A
# 2   350.0      2353.096253         7.609         N/A   N/A
# 3   200.0      2264.162353         7.903         N/A   N/A
# 4    80.0      2150.000000         8.068         N/A   N/A

# %%
fact_table.shape
# Out:
# (50, 13)

# %%
# --- Final TMDB fetch (used in final pipeline) ---
# def final_tmdb_version():


# Import necessary libraries
# - requests: For making HTTP requests to APIs
# - pandas: For handling data in DataFrames (like tables)
# - time: For adding delays to avoid overwhelming servers
import requests
import pandas as pd
import time

# Configuration settings

TMDB_API_KEY = '2762321c463faabbba42b561409706aa'
OMDB_API_KEY = '45e74674'

# Module 1: Fetch top movies from TMDB (sorted by revenue.desc)
# This function uses TMDB's discover/movie endpoint to get top-grossing films.
# It returns a DataFrame with columns: Title, Year, TMDB_ID
def fetch_top_movies_from_tmdb(num_movies=1000, min_year=2010):
    """
    Fetch top-grossing movies from TMDB using discover/movie sorted by revenue.desc.

    This function:
    1. Constructs the API URL with sort_by=revenue.desc and pagination.
    2. Optionally filters by minimum year (e.g., primary_release_year.gte=2010).
    3. Extracts title, year (from release_date), and ID for each movie.
    4. Stops once num_movies is reached.

    Args:
        num_movies (int): How many top movies to fetch (default 50).
        min_year (int): Optional minimum release year (e.g., 2010 for recent data).

    Returns:
        pd.DataFrame: A table with basic movie info (Title, Year, TMDB_ID).
    """
    movies = []
    page = 1
    while len(movies) < num_movies:
        # Construct URL with sort_by=revenue.desc
        url = f"https://api.themoviedb.org/3/discover/movie?api_key={TMDB_API_KEY}&sort_by=revenue.desc&page={page}"
        if min_year:
            url += f"&primary_release_year.gte={min_year}"  # Filter for recent years if specified
        response = requests.get(url).json()

        if 'results' not in response or not response['results']:
            break  # No more results

        for movie in response['results']:
            year = movie.get('release_date', '')[:4]  # Extract year from release_date
            if year:  # Skip if no release date
                movies.append({
                    'Title': movie['title'],
                    'Year': year,
                    'TMDB_ID': movie['id']
                })
            if len(movies) >= num_movies:
                break

        page += 1
        time.sleep(1)  # Delay to avoid rate limits

    if not movies:
        print("No movies fetched from TMDB. Check API key or parameters.")
        return pd.DataFrame()

    return pd.DataFrame(movies)

# Module 2: Fetch details from TMDB for a single movie using ID
# This function queries TMDB's movie/{id} endpoint for details.
def fetch_tmdb_details(movie_id):
    """
    Fetch movie details from TMDB API for a single movie using its ID.

    This function:
    1. Fetches detailed info including credits (cast and crew).
    2. Extracts features like genre, director, actors, release_date, runtime, budget, revenue (as Worldwide_Gross), vote_average.

    Args:
        movie_id (int): TMDB movie ID.

    Returns:
        dict: A dictionary with TMDB features (or 'N/A' if not found).
    """
    # Default dictionary with 'N/A' values
    movie_data = {
        'Genre': 'N/A',
        'Director': 'N/A',
        'Actors': 'N/A',
        'Release_Date': 'N/A',
        'Runtime': 'N/A',
        'Budget': 'N/A',
        'Worldwide_Gross': 'N/A',  # Use revenue as gross
        'Vote_Average': 'N/A'
    }

    try:
        # Construct details URL with credits appended
        details_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={TMDB_API_KEY}&append_to_response=credits"
        details_response = requests.get(details_url).json()

        if 'status_code' in details_response and details_response['status_code'] != 200:
            raise Exception(details_response.get('status_message', 'Unknown error'))

        # Extract genres as comma-separated string
        movie_data['Genre'] = ', '.join([genre['name'] for genre in details_response.get('genres', [])])

        # Find director from crew list
        director = next((member['name'] for member in details_response['credits'].get('crew', []) if member['job'] == 'Director'), 'N/A')
        movie_data['Director'] = director

        # Get top 5 actors from cast
        actors = details_response['credits'].get('cast', [])[:5]
        movie_data['Actors'] = ', '.join([actor['name'] for actor in actors])

        # Other details
        movie_data['Release_Date'] = details_response.get('release_date', 'N/A')
        movie_data['Runtime'] = details_response.get('runtime', 'N/A')
        movie_data['Budget'] = details_response.get('budget', 'N/A')
        movie_data['Worldwide_Gross'] = details_response.get('revenue', 'N/A')  # Revenue as gross
        movie_data['Vote_Average'] = details_response.get('vote_average', 'N/A')

        time.sleep(1)  # Delay to avoid hitting API rate limits
        return movie_data
    except Exception as e:
        print(f"Error with TMDB for movie ID {movie_id}: {e}")
        return movie_data

# This function applies fetch_tmdb_details to all rows in a DataFrame using TMDB_ID
def enhance_with_tmdb(df):
    """
    Enhance the entire DataFrame with TMDB details using TMDB_ID.

    This loops through each row, fetches details by ID, and adds them to the DataFrame.

    Args:
        df (pd.DataFrame): Input DataFrame with 'TMDB_ID'.

    Returns:
        pd.DataFrame: DataFrame with added TMDB columns.
    """
    tmdb_data = []
    for _, row in df.iterrows():
        details = fetch_tmdb_details(row['TMDB_ID'])
        tmdb_data.append(details)

    tmdb_df = pd.DataFrame(tmdb_data)
    return pd.concat([df, tmdb_df], axis=1)

# Module 3: Fetch IMDB details using OMDb API
def fetch_imdb_details(title, year):
    """
    Fetch IMDB rating and votes using OMDb API.

    Args:
        title (str): Movie title.
        year (str): Release year.

    Returns:
        dict: Dictionary with IMDB rating and votes (or 'N/A').
    """
    try:
        # Construct OMDb URL
        url = f"http://www.omdbapi.com/?t={title}&y={year}&apikey={OMDB_API_KEY}"
        response = requests.get(url).json()

        if response['Response'] == 'True':
            return {
                'IMDB_Rating': response.get('imdbRating', 'N/A'),
                'Votes': response.get('imdbVotes', 'N/A')
            }
        else:
            print(f"OMDb error for {title}: {response.get('Error', 'Unknown')}")
            return {'IMDB_Rating': 'N/A', 'Votes': 'N/A'}

        time.sleep(1)  # Delay for rate limiting
    except Exception as e:
        print(f"Error with OMDb for {title}: {e}")
        return {'IMDB_Rating': 'N/A', 'Votes': 'N/A'}

# This function applies fetch_imdb_details to all rows
def enhance_with_imdb(df):
    """
    Enhance the DataFrame with IMDB details using OMDb API.

    Args:
        df (pd.DataFrame): Input DataFrame with 'Title' and 'Year'.

    Returns:
        pd.DataFrame: DataFrame with added IMDB columns.
    """
    imdb_data = []
    for _, row in df.iterrows():
        details = fetch_imdb_details(row['Title'], row['Year'])
        imdb_data.append(details)

    imdb_df = pd.DataFrame(imdb_data)
    return pd.concat([df, imdb_df], axis=1)

# Module 4: Clean the data
# Converts financial columns to numeric values in millions.
def clean_data(df):
    """
    Clean the DataFrame by converting financials to numbers (in millions).

    This handles:
    - Converting Worldwide_Gross, Budget, and Revenue (if present) to floats divided by 1,000,000.
    - Handles 'N/A' as NaN.

    Args:
        df (pd.DataFrame): Input DataFrame.

    Returns:
        pd.DataFrame: Cleaned DataFrame.
    """
    df['Worldwide_Gross'] = pd.to_numeric(df['Worldwide_Gross'], errors='coerce') / 1000000
    df['Budget'] = pd.to_numeric(df['Budget'], errors='coerce') / 1000000
    return df

# Module 5: Build the full fact table
# This orchestrates everything: fetch top movies, enhance with details, clean, save.
# Min Movies limited to 1000 due to oMDB having a limit of 1000 movies per API key per day
def build_fact_table(num_movies=1000, min_year=2010, use_imdb=True):
    """
    Build the complete fact table using only TMDB.

    Steps:
    1. Fetch top movies from TMDB (sorted by revenue.desc, optional min_year filter).
    2. Add TMDB details using movie IDs.
    3. Optionally add IMDB details using OMDb API.
    4. Clean the data.
    5. Save to CSV.

    Args:
        num_movies (int): Number of movies to process.
        min_year (int): Minimum release year (default 2010 for recent data; set to None for all time).
        use_imdb (bool): Whether to include IMDB data (default True).

    Returns:
        pd.DataFrame: The final fact table.
    """
    # Step 1: Get top movies from TMDB
    df = fetch_top_movies_from_tmdb(num_movies, min_year)
    if df.empty:
        return df
    # Step 2: Add TMDB details
    df = enhance_with_tmdb(df)
    # Step 3: Add IMDB if requested (using OMDb)
    if use_imdb:
        df = enhance_with_imdb(df)
    # Step 4: Clean
    df = clean_data(df)

    # Save the DataFrame to a CSV file
    df.to_csv('movie_fact_table.csv', index=False)
    print("Fact table saved to movie_fact_table.csv")
    return df

# Run the script when executed directly
# This is the entry point: calls build_fact_table and prints the first few rows
# Adjust min_year as needed (e.g., None for all time, or 2000 for broader data)
if __name__ == "__main__":
    fact_table = build_fact_table(min_year=2010)  # Example: data from 2010 onward
    print(fact_table.head())
# Out:
# OMDb error for Avatar: Request limit reached!
# OMDb error for Avengers: Endgame: Request limit reached!
# OMDb error for Avatar: The Way of Water: Request limit reached!
# OMDb error for Titanic: Request limit reached!
# OMDb error for Ne Zha 2: Request limit reached!
# OMDb error for Star Wars: The Force Awakens: Request limit reached!
# OMDb error for Avengers: Infinity War: Request limit reached!
# OMDb error for Spider-Man: No Way Home: Request limit reached!
# OMDb error for Inside Out 2: Request limit reached!
# OMDb error for Jurassic World: Request limit reached!
# OMDb error for The Lion King: Request limit reached!
# OMDb error for The Avengers: Request limit reached!
# OMDb error for Furious 7: Request limit reached!
# OMDb error for Top Gun: Maverick: Request limit reached!
# OMDb error for Frozen II: Request limit reached!
# OMDb error for Barbie: Request limit reached!
# OMDb error for Avengers: Age of Ultron: Request limit reached!
# OMDb error for The Super Mario Bros. Movie: Request limit reached!
# OMDb error for Black Panther: Request limit reached!
# OMDb error for Harry Potter and the Deathly Hallows: Part 2: Request limit reached!
# OMDb error for Deadpool & Wolverine: Request limit reached!
# OMDb error for Star Wars: The Last Jedi: Request limit reached!
# OMDb error for Jurassic World: Fallen Kingdom: Request limit reached!
# OMDb error for Frozen: Request limit reached!
# OMDb error for Beauty and the Beast: Request limit reached!
# OMDb error for Incredibles 2: Request limit reached!
# OMDb error for The Fate of the Furious: Request limit reached!
# OMDb error for Iron Man 3: Request limit reached!
# OMDb error for Minions: Request limit reached!
# OMDb error for Captain America: Civil War: Request limit reached!
# OMDb error for Aquaman: Request limit reached!
# OMDb error for Zootopia 2: Request limit reached!
# OMDb error for Spider-Man: Far From Home: Request limit reached!
# OMDb error for Captain Marvel: Request limit reached!
# OMDb error for Transformers: Dark of the Moon: Request limit reached!
# OMDb error for The Lord of the Rings: The Return of the King: Request limit reached!
# OMDb error for Skyfall: Request limit reached!
# OMDb error for Transformers: Age of Extinction: Request limit reached!
# OMDb error for Aladdin: Request limit reached!
# OMDb error for The Dark Knight Rises: Request limit reached!
# OMDb error for Joker: Request limit reached!
# OMDb error for Star Wars: The Rise of Skywalker: Request limit reached!
# OMDb error for Toy Story 4: Request limit reached!
# OMDb error for Toy Story 3: Request limit reached!
# OMDb error for Pirates of the Caribbean: Dead Man's Chest: Request limit reached!
# OMDb error for Moana 2: Request limit reached!
# OMDb error for Rogue One: A Star Wars Story: Request limit reached!
# OMDb error for Pirates of the Caribbean: On Stranger Tides: Request limit reached!
# OMDb error for Lilo & Stitch: Request limit reached!
# OMDb error for Despicable Me 3: Request limit reached!
# OMDb error for Finding Dory: Request limit reached!
# OMDb error for Zootopia: Request limit reached!
# OMDb error for Alice in Wonderland: Request limit reached!
# OMDb error for The Hobbit: An Unexpected Journey: Request limit reached!
# OMDb error for The Dark Knight: Request limit reached!
# OMDb error for Jurassic World Dominion: Request limit reached!
# OMDb error for Jumanji: Welcome to the Jungle: Request limit reached!
# OMDb error for Santa: Request limit reached!
# OMDb error for Harry Potter and the Philosopher's Stone: Request limit reached!
# OMDb error for Despicable Me 2: Request limit reached!
# OMDb error for Despicable Me 4: Request limit reached!
# OMDb error for The Jungle Book: Request limit reached!
# OMDb error for Pirates of the Caribbean: At World's End: Request limit reached!
# OMDb error for The Hobbit: The Desolation of Smaug: Request limit reached!
# OMDb error for A Minecraft Movie: Request limit reached!
# OMDb error for The Hobbit: The Battle of the Five Armies: Request limit reached!
# OMDb error for Doctor Strange in the Multiverse of Madness: Request limit reached!
# OMDb error for Harry Potter and the Deathly Hallows: Part 1: Request limit reached!
# OMDb error for Oppenheimer: Request limit reached!
# OMDb error for Finding Nemo: Request limit reached!
# OMDb error for Minions: The Rise of Gru: Request limit reached!
# OMDb error for Harry Potter and the Order of the Phoenix: Request limit reached!
# OMDb error for Shrek 2: Request limit reached!
# OMDb error for Harry Potter and the Half-Blood Prince: Request limit reached!
# OMDb error for The Lord of the Rings: The Two Towers: Request limit reached!
# OMDb error for Star Wars: Episode I - The Phantom Menace: Request limit reached!
# OMDb error for Jurassic Park: Request limit reached!
# OMDb error for Bohemian Rhapsody: Request limit reached!
# OMDb error for The Battle at Lake Changjin: Request limit reached!
# OMDb error for Harry Potter and the Goblet of Fire: Request limit reached!
# OMDb error for Spider-Man 3: Request limit reached!
# OMDb error for Ice Age: Dawn of the Dinosaurs: Request limit reached!
# OMDb error for Spectre: Request limit reached!
# OMDb error for Spider-Man: Homecoming: Request limit reached!
# OMDb error for Ice Age: Continental Drift: Request limit reached!
# OMDb error for Harry Potter and the Chamber of Secrets: Request limit reached!
# OMDb error for The Secret Life of Pets: Request limit reached!
# OMDb error for Batman v Superman: Dawn of Justice: Request limit reached!
# OMDb error for The Lord of the Rings: The Fellowship of the Ring: Request limit reached!
# OMDb error for Wolf Warrior 2: Request limit reached!
# OMDb error for Jurassic World Rebirth: Request limit reached!
# OMDb error for The Hunger Games: Catching Fire: Request limit reached!
# OMDb error for Guardians of the Galaxy Vol. 2: Request limit reached!
# OMDb error for Black Panther: Wakanda Forever: Request limit reached!
# OMDb error for Inside Out: Request limit reached!
# OMDb error for Venom: Request limit reached!
# OMDb error for Thor: Ragnarok: Request limit reached!
# OMDb error for Star Wars: Episode III - Revenge of the Sith: Request limit reached!
# OMDb error for Guardians of the Galaxy Vol. 3: Request limit reached!
# OMDb error for Inception: Request limit reached!
# OMDb error for Transformers: Revenge of the Fallen: Request limit reached!
# OMDb error for The Twilight Saga: Breaking Dawn - Part 2: Request limit reached!
# OMDb error for Wonder Woman: Request limit reached!
# OMDb error for Hi, Mom: Request limit reached!
# OMDb error for Spider-Man: Request limit reached!
# OMDb error for Independence Day: Request limit reached!
# OMDb error for Coco: Request limit reached!
# OMDb error for Shrek the Third: Request limit reached!
# OMDb error for Fantastic Beasts and Where to Find Them: Request limit reached!
# OMDb error for Jumanji: The Next Level: Request limit reached!
# OMDb error for E.T. the Extra-Terrestrial: Request limit reached!
# OMDb error for Pirates of the Caribbean: Dead Men Tell No Tales: Request limit reached!
# OMDb error for Mission: Impossible - Fallout: Request limit reached!
# OMDb error for 2012: Request limit reached!
# OMDb error for Harry Potter and the Prisoner of Azkaban: Request limit reached!
# OMDb error for Spider-Man 2: Request limit reached!
# OMDb error for Fast & Furious 6: Request limit reached!
# OMDb error for Indiana Jones and the Kingdom of the Crystal Skull: Request limit reached!
# OMDb error for Deadpool 2: Request limit reached!
# OMDb error for Deadpool: Request limit reached!
# OMDb error for Star Wars: Request limit reached!
# OMDb error for No Time to Die: Request limit reached!
# OMDb error for Guardians of the Galaxy: Request limit reached!
# OMDb error for The Batman: Request limit reached!
# OMDb error for Demon Slayer: Kimetsu no Yaiba Infinity Castle: Request limit reached!
# OMDb error for The Lion King: Request limit reached!
# OMDb error for Thor: Love and Thunder: Request limit reached!
# OMDb error for Fast & Furious Presents: Hobbs & Shaw: Request limit reached!
# OMDb error for The Da Vinci Code: Request limit reached!
# OMDb error for Wicked: Request limit reached!
# OMDb error for Maleficent: Request limit reached!
# OMDb error for The Amazing Spider-Man: Request limit reached!
# OMDb error for The Hunger Games: Mockingjay - Part 1: Request limit reached!
# OMDb error for Shrek Forever After: Request limit reached!
# OMDb error for Suicide Squad: Request limit reached!
# OMDb error for Madagascar 3: Europe's Most Wanted: Request limit reached!
# OMDb error for Interstellar: Request limit reached!
# OMDb error for X-Men: Days of Future Past: Request limit reached!
# OMDb error for Aladdin - The Broadway Muscial: Request limit reached!
# OMDb error for The Chronicles of Narnia: The Lion, the Witch and the Wardrobe: Request limit reached!
# OMDb error for Monsters University: Request limit reached!
# OMDb error for Ne Zha: Request limit reached!
# OMDb error for The Matrix Reloaded: Request limit reached!
# OMDb error for Up: Request limit reached!
# OMDb error for F9: Request limit reached!
# OMDb error for Gravity: Request limit reached!
# OMDb error for Mufasa: The Lion King: Request limit reached!
# OMDb error for Dune: Part Two: Request limit reached!
# OMDb error for Captain America: The Winter Soldier: Request limit reached!
# OMDb error for The Twilight Saga: Breaking Dawn - Part 1: Request limit reached!
# OMDb error for Dawn of the Planet of the Apes: Request limit reached!
# OMDb error for The Twilight Saga: New Moon: Request limit reached!
# OMDb error for Transformers: Request limit reached!
# OMDb error for The Amazing Spider-Man 2: Request limit reached!
# OMDb error for Fast X: Request limit reached!
# OMDb error for It: Request limit reached!
# OMDb error for The Twilight Saga: Eclipse: Request limit reached!
# OMDb error for Mission: Impossible - Ghost Protocol: Request limit reached!
# OMDb error for The Hunger Games: Request limit reached!
# OMDb error for Spider-Man: Across the Spider-Verse: Request limit reached!
# OMDb error for Moana: Request limit reached!
# OMDb error for Detective Chinatown 3: Request limit reached!
# OMDb error for Mission: Impossible - Rogue Nation: Request limit reached!
# OMDb error for Forrest Gump: Request limit reached!
# OMDb error for Doctor Strange: Request limit reached!
# OMDb error for Full River Red: Request limit reached!
# OMDb error for The Sixth Sense: Request limit reached!
# OMDb error for Man of Steel: Request limit reached!
# OMDb error for Kung Fu Panda 2: Request limit reached!
# OMDb error for Justice League: Request limit reached!
# OMDb error for Ice Age: The Meltdown: Request limit reached!
# OMDb error for Big Hero 6: Request limit reached!
# OMDb error for Pirates of the Caribbean: The Curse of the Black Pearl: Request limit reached!
# OMDb error for Fantastic Beasts: The Crimes of Grindelwald: Request limit reached!
# OMDb error for Men in Black 3: Request limit reached!
# OMDb error for The Hunger Games: Mockingjay - Part 2: Request limit reached!
# OMDb error for Star Wars: Episode II - Attack of the Clones: Request limit reached!
# OMDb error for Thor: The Dark World: Request limit reached!
# OMDb error for How to Train Your Dragon: Request limit reached!
# OMDb error for Wonka: Request limit reached!
# OMDb error for Sing: Request limit reached!
# OMDb error for Kung Fu Panda: Request limit reached!
# OMDb error for F1: Request limit reached!
# OMDb error for The Incredibles: Request limit reached!
# OMDb error for The Martian: Request limit reached!
# OMDb error for Hancock: Request limit reached!
# OMDb error for The Battle at Lake Changjin II: Water Gate Bridge: Request limit reached!
# OMDb error for Fast Five: Request limit reached!
# OMDb error for Iron Man 2: Request limit reached!
# OMDb error for Ratatouille: Request limit reached!
# OMDb error for Ant-Man and the Wasp: Request limit reached!
# OMDb error for How to Train Your Dragon 2: Request limit reached!
# OMDb error for Logan: Request limit reached!
# OMDb error for The Lost World: Jurassic Park: Request limit reached!
# OMDb error for Superman: Request limit reached!
# OMDb error for The Passion of the Christ: Request limit reached!
# OMDb error for Mamma Mia!: Request limit reached!
# OMDb error for Life of Pi: Request limit reached!
# OMDb error for Ready Player One: Request limit reached!
# OMDb error for Transformers: The Last Knight: Request limit reached!
# OMDb error for Madagascar: Escape 2 Africa: Request limit reached!
# OMDb error for War of the Worlds: Request limit reached!
# OMDb error for Casino Royale: Request limit reached!
# OMDb error for Mission: Impossible - The Final Reckoning: Request limit reached!
# OMDb error for Tangled: Request limit reached!
# OMDb error for Quantum of Solace: Request limit reached!
# OMDb error for Men in Black: Request limit reached!
# OMDb error for The Croods: Request limit reached!
# OMDb error for The Hangover Part II: Request limit reached!
# OMDb error for I Am Legend: Request limit reached!
# OMDb error for Iron Man: Request limit reached!
# OMDb error for Monsters, Inc.: Request limit reached!
# OMDb error for Operation Red Sea: Request limit reached!
# OMDb error for Night at the Museum: Request limit reached!
# OMDb error for Return of the Jedi: Request limit reached!
# OMDb error for Godzilla x Kong: The New Empire: Request limit reached!
# OMDb error for Mission: Impossible - Dead Reckoning Part One: Request limit reached!
# OMDb error for Fifty Shades of Grey: Request limit reached!
# OMDb error for The Little Mermaid: Request limit reached!
# OMDb error for Kong: Skull Island: Request limit reached!
# OMDb error for The Smurfs: Request limit reached!
# OMDb error for King Kong: Request limit reached!
# OMDb error for Cars 2: Request limit reached!
# OMDb error for Puss in Boots: Request limit reached!
# OMDb error for The Mermaid: Request limit reached!
# OMDb error for Armageddon: Request limit reached!
# OMDb error for The Day After Tomorrow: Request limit reached!
# OMDb error for Ted: Request limit reached!
# OMDb error for Kung Fu Panda 4: Request limit reached!
# OMDb error for Mission: Impossible II: Request limit reached!
# OMDb error for Detective Chinatown 2: Request limit reached!
# OMDb error for X-Men: Apocalypse: Request limit reached!
# OMDb error for Cinderella: Request limit reached!
# OMDb error for Despicable Me: Request limit reached!
# OMDb error for American Sniper: Request limit reached!
# OMDb error for Madagascar: Request limit reached!
# OMDb error for How to Train Your Dragon: The Hidden World: Request limit reached!
# OMDb error for Brave: Request limit reached!
# OMDb error for The Empire Strikes Back: Request limit reached!
# OMDb error for The Revenant: Request limit reached!
# OMDb error for World War Z: Request limit reached!
# OMDb error for The Meg: Request limit reached!
# OMDb error for Ralph Breaks the Internet: Request limit reached!
# OMDb error for Hotel Transylvania 3: Summer Vacation: Request limit reached!
# OMDb error for The Boss Baby: Request limit reached!
# OMDb error for The Simpsons Movie: Request limit reached!
# OMDb error for Dunkirk: Request limit reached!
# OMDb error for Godzilla: Request limit reached!
# OMDb error for Sherlock Holmes: Request limit reached!
# OMDb error for Demon Slayer -Kimetsu no Yaiba- The Movie: Mugen Train: Request limit reached!
# OMDb error for The Fantastic 4: First Steps: Request limit reached!
# OMDb error for WALL·E: Request limit reached!
# OMDb error for Kung Fu Panda 3: Request limit reached!
# OMDb error for Terminator 2: Judgment Day: Request limit reached!
# OMDb error for Ant-Man: Request limit reached!
# OMDb error for Meet the Fockers: Request limit reached!
# OMDb error for La La Land: Request limit reached!
# OMDb error for The Grinch: Request limit reached!
# OMDb error for Venom: Let There Be Carnage: Request limit reached!
# OMDb error for Ghost: Request limit reached!
# OMDb error for Aladdin: Request limit reached!
# OMDb error for Dunki: Request limit reached!
# OMDb error for The World of the Pharaoh (Live Theatre): Request limit reached!
# OMDb error for Rio 2: Request limit reached!
# OMDb error for Troy: Request limit reached!
# OMDb error for Toy Story 2: Request limit reached!
# OMDb error for Elemental: Request limit reached!
# OMDb error for How to Train Your Dragon: Request limit reached!
# OMDb error for The Conjuring: Last Rites: Request limit reached!
# OMDb error for Twister: Request limit reached!
# OMDb error for Clash of the Titans: Request limit reached!
# OMDb error for Sonic the Hedgehog 3: Request limit reached!
# OMDb error for Oz the Great and Powerful: Request limit reached!
# OMDb error for Maleficent: Mistress of Evil: Request limit reached!
# OMDb error for War for the Planet of the Apes: Request limit reached!
# OMDb error for Shrek: Request limit reached!
# OMDb error for Mr. & Mrs. Smith: Request limit reached!
# OMDb error for Angels & Demons: Request limit reached!
# OMDb error for Teenage Mutant Ninja Turtles: Request limit reached!
# OMDb error for Puss in Boots: The Last Wish: Request limit reached!
# OMDb error for Bruce Almighty: Request limit reached!
# OMDb error for Rio: Request limit reached!
# OMDb error for Saving Private Ryan: Request limit reached!
# OMDb error for Rise of the Planet of the Apes: Request limit reached!
# OMDb error for Venom: The Last Dance: Request limit reached!
# OMDb error for Home Alone: Request limit reached!
# OMDb error for Ant-Man and the Wasp: Quantumania: Request limit reached!
# OMDb error for Charlie and the Chocolate Factory: Request limit reached!
# OMDb error for Indiana Jones and the Last Crusade: Request limit reached!
# OMDb error for San Andreas: Request limit reached!
# OMDb error for Hotel Transylvania 2: Request limit reached!
# OMDb error for It Chapter Two: Request limit reached!
# OMDb error for Wreck-It Ralph: Request limit reached!
# OMDb error for The Lego Movie: Request limit reached!
# OMDb error for Jaws: Request limit reached!
# OMDb error for Godzilla vs. Kong: Request limit reached!
# OMDb error for The Hangover: Request limit reached!
# OMDb error for Lucy: Request limit reached!
# OMDb error for Bumblebee: Request limit reached!
# OMDb error for Star Trek Into Darkness: Request limit reached!
# OMDb error for Gladiator: Request limit reached!
# OMDb error for The Matrix: Request limit reached!
# OMDb error for Pretty Woman: Request limit reached!
# OMDb error for Gladiator II: Request limit reached!
# OMDb error for Cars: Request limit reached!
# OMDb error for The Eight Hundred: Request limit reached!
# OMDb error for Moon Man: Request limit reached!
# OMDb error for X-Men: The Last Stand: Request limit reached!
# OMDb error for National Treasure: Book of Secrets: Request limit reached!
# OMDb error for The Greatest Showman: Request limit reached!
# OMDb error for Mission: Impossible: Request limit reached!
# OMDb error for The Last Samurai: Request limit reached!
# OMDb error for 300: Request limit reached!
# OMDb error for Detective Chinatown 1900: Request limit reached!
# OMDb error for Beetlejuice Beetlejuice: Request limit reached!
# OMDb error for Ocean's Eleven: Request limit reached!
# OMDb error for My People, My Country: Request limit reached!
# OMDb error for Wicked: For Good: Request limit reached!
# OMDb error for Pokémon Detective Pikachu: Request limit reached!
# OMDb error for Thor: Request limit reached!
# OMDb error for Pearl Harbor: Request limit reached!
# OMDb error for Tarzan: Request limit reached!
# OMDb error for 1917: Request limit reached!
# OMDb error for Men in Black II: Request limit reached!
# OMDb error for The Mummy Returns: Request limit reached!
# OMDb error for Alvin and the Chipmunks: The Squeakquel: Request limit reached!
# OMDb error for The Bourne Ultimatum: Request limit reached!
# OMDb error for Les Misérables: Request limit reached!
# OMDb error for Transformers: Rise of the Beasts: Request limit reached!
# OMDb error for The Exorcist: Request limit reached!
# OMDb error for Mrs. Doubtfire: Request limit reached!
# OMDb error for Terminator Genisys: Request limit reached!
# OMDb error for Aquaman and the Lost Kingdom: Request limit reached!
# OMDb error for John Wick: Chapter 4: Request limit reached!
# OMDb error for A Star Is Born: Request limit reached!
# OMDb error for Terminator 3: Rise of the Machines: Request limit reached!
# OMDb error for Warcraft: Request limit reached!
# OMDb error for Yolo: Request limit reached!
# OMDb error for Shang-Chi and the Legend of the Ten Rings: Request limit reached!
# OMDb error for Die Another Day: Request limit reached!
# OMDb error for Cast Away: Request limit reached!
# OMDb error for The Secret Life of Pets 2: Request limit reached!
# OMDb error for Rampage: Request limit reached!
# OMDb error for Metallica: WorldWired Tour - Live in Manchester, England - June 18, 2019: Request limit reached!
# OMDb error for The Intouchables: Request limit reached!
# OMDb error for Bad Boys for Life: Request limit reached!
# OMDb error for Django Unchained: Request limit reached!
# OMDb error for The Matrix Revolutions: Request limit reached!
# OMDb error for Beauty and the Beast: Request limit reached!
# OMDb error for Dances with Wolves: Request limit reached!
# OMDb error for Pegasus 2: Request limit reached!
# OMDb error for Successor: Request limit reached!
# OMDb error for The Chronicles of Narnia: Prince Caspian: Request limit reached!
# OMDb error for Sex and the City: Request limit reached!
# OMDb error for The Mummy: Request limit reached!
# OMDb error for The Chronicles of Narnia: The Voyage of the Dawn Treader: Request limit reached!
# OMDb error for Jason Bourne: Request limit reached!
# OMDb error for The Wolverine: Request limit reached!
# OMDb error for Captain America: Brave New World: Request limit reached!
# OMDb error for Kingsman: The Secret Service: Request limit reached!
# OMDb error for The King's Speech: Request limit reached!
# OMDb error for Night at the Museum: Battle of the Smithsonian: Request limit reached!
# OMDb error for Batman: Request limit reached!
# OMDb error for The Bodyguard: Request limit reached!
# OMDb error for Pacific Rim: Request limit reached!
# OMDb error for Kingsman: The Golden Circle: Request limit reached!
# OMDb error for TRON: Legacy: Request limit reached!
# OMDb error for The Mummy: Request limit reached!
# OMDb error for Ice Age: Collision Course: Request limit reached!
# OMDb error for Sing 2: Request limit reached!
# OMDb error for Signs: Request limit reached!
# OMDb error for X2: Request limit reached!
# OMDb error for Dune: Request limit reached!
# OMDb error for Fantastic Beasts: The Secrets of Dumbledore: Request limit reached!
# OMDb error for Uncharted: Request limit reached!
# OMDb error for The Wolf of Wall Street: Request limit reached!
# OMDb error for Sonic the Hedgehog 2: Request limit reached!
# OMDb error for Alita: Battle Angel: Request limit reached!
# OMDb error for Bad Boys: Ride or Die: Request limit reached!
# OMDb error for The Mummy: Tomb of the Dragon Emperor: Request limit reached!
# OMDb error for Prometheus: Request limit reached!
# OMDb error for Gone with the Wind: Request limit reached!
# OMDb error for Eternals: Request limit reached!
# OMDb error for Enter the Dragon: Request limit reached!
# OMDb error for Mission: Impossible III: Request limit reached!
# OMDb error for Kingdom of the Planet of the Apes: Request limit reached!
# OMDb error for Snow White and the Huntsman: Request limit reached!
# OMDb error for Grease: Request limit reached!
# OMDb error for Mamma Mia! Here We Go Again: Request limit reached!
# OMDb error for Toy Story: Request limit reached!
# OMDb error for Twilight: Request limit reached!
# OMDb error for Spider-Man: Into the Spider-Verse: Request limit reached!
# OMDb error for Black Adam: Request limit reached!
# OMDb error for Too Cool to Kill: Request limit reached!
# OMDb error for Solo: A Star Wars Story: Request limit reached!
# OMDb error for Once Upon a Time... in Hollywood: Request limit reached!
# OMDb error for Superman Returns: Request limit reached!
# OMDb error for Robin Hood: Prince of Thieves: Request limit reached!
# OMDb error for Raiders of the Lost Ark: Request limit reached!
# OMDb error for Independence Day: Resurgence: Request limit reached!
# OMDb error for Godzilla: King of the Monsters: Request limit reached!
# OMDb error for Monster Hunt: Request limit reached!
# OMDb error for Star Trek: Request limit reached!
# OMDb error for Happy Feet: Request limit reached!
# OMDb error for Meg 2: The Trench: Request limit reached!
# OMDb error for Indiana Jones and the Dial of Destiny: Request limit reached!
# OMDb error for Cars 3: Request limit reached!
# OMDb error for Live Free or Die Hard: Request limit reached!
# OMDb error for Ice Age: Request limit reached!
# OMDb error for Thunderbolts*: Request limit reached!
# OMDb error for Dead to Rights: Request limit reached!
# OMDb error for Fifty Shades Darker: Request limit reached!
# OMDb error for Monsters vs Aliens: Request limit reached!
# OMDb error for Back to the Future: Request limit reached!
# OMDb error for Black Widow: Request limit reached!
# OMDb error for Godzilla: Request limit reached!
# OMDb error for True Lies: Request limit reached!
# OMDb error for Mad Max: Fury Road: Request limit reached!
# OMDb error for Slumdog Millionaire: Request limit reached!
# OMDb error for The Jungle Book: Request limit reached!
# OMDb error for Limonov: The Ballad: Request limit reached!
# OMDb error for Taken 2: Request limit reached!
# OMDb error for Hello Mr. Billionaire: Request limit reached!
# OMDb error for Batman Begins: Request limit reached!
# OMDb error for What Women Want: Request limit reached!
# OMDb error for The Adventures of Tintin: Request limit reached!
# OMDb error for Penguins of Madagascar: Request limit reached!
# OMDb error for X-Men Origins: Wolverine: Request limit reached!
# OMDb error for Twisters: Request limit reached!
# OMDb error for The Golden Compass: Request limit reached!
# OMDb error for Fifty Shades Freed: Request limit reached!
# OMDb error for G.I. Joe: Retaliation: Request limit reached!
# OMDb error for Hitch: Request limit reached!
# OMDb error for Terminator Salvation: Request limit reached!
# OMDb error for Gone Girl: Request limit reached!
# OMDb error for Captain America: The First Avenger: Request limit reached!
# OMDb error for Edge of Tomorrow: Request limit reached!
# OMDb error for There's Something About Mary: Request limit reached!
# OMDb error for Creation of the Gods I: Kingdom of Storms: Request limit reached!
# OMDb error for Home: Request limit reached!
# OMDb error for Jurassic Park III: Request limit reached!
# OMDb error for My Big Fat Greek Wedding: Request limit reached!
# OMDb error for Shazam!: Request limit reached!
# OMDb error for Shark Tale: Request limit reached!
# OMDb error for Die Hard: With a Vengeance: Request limit reached!
# OMDb error for The Nun: Request limit reached!
# OMDb error for Sinners: Request limit reached!
# OMDb error for Tenet: Request limit reached!
# OMDb error for Notting Hill: Request limit reached!
# OMDb error for A Bug's Life: Request limit reached!
# OMDb error for Night at the Museum: Secret of the Tomb: Request limit reached!
# OMDb error for Fast & Furious: Request limit reached!
# OMDb error for Ocean's Twelve: Request limit reached!
# OMDb error for Noah: Request limit reached!
# OMDb error for Planet of the Apes: Request limit reached!
# OMDb error for The Hangover Part III: Request limit reached!
# OMDb error for The World Is Not Enough: Request limit reached!
# OMDb error for Monster Hunt 2: Request limit reached!
# OMDb error for Alvin and the Chipmunks: Request limit reached!
# OMDb error for The Karate Kid: Request limit reached!
# OMDb error for Home Alone 2: Lost in New York: Request limit reached!
# OMDb error for Hotel Transylvania: Request limit reached!
# OMDb error for Minority Report: Request limit reached!
# OMDb error for Your Name.: Request limit reached!
# OMDb error for Top Gun: Request limit reached!
# OMDb error for The Legend of Tarzan: Request limit reached!
# OMDb error for American Beauty: Request limit reached!
# OMDb error for Journey 2: The Mysterious Island: Request limit reached!
# OMDb error for Apollo 13: Request limit reached!
# OMDb error for Rain Man: Request limit reached!
# OMDb error for Dinosaur: Request limit reached!
# OMDb error for X-Men: First Class: Request limit reached!
# OMDb error for Dumbo: Request limit reached!
# OMDb error for Basic Instinct: Request limit reached!
# OMDb error for Murder on the Orient Express: Request limit reached!
# OMDb error for GoldenEye: Request limit reached!
# OMDb error for Catch Me If You Can: Request limit reached!
# OMDb error for Now You See Me: Request limit reached!
# OMDb error for Hannibal: Request limit reached!
# OMDb error for The Mask: Request limit reached!
# OMDb error for Peter Rabbit: Request limit reached!
# OMDb error for The Great Gatsby: Request limit reached!
# OMDb error for It Ends with Us: Request limit reached!
# OMDb error for Alien: Romulus: Request limit reached!
# OMDb error for Speed: Request limit reached!
# OMDb error for The Angry Birds Movie: Request limit reached!
# OMDb error for Deep Impact: Request limit reached!
# OMDb error for The Lorax: Request limit reached!
# OMDb error for Mary Poppins Returns: Request limit reached!
# OMDb error for The Maze Runner: Request limit reached!
# OMDb error for National Treasure: Request limit reached!
# OMDb error for The Smurfs 2: Request limit reached!
# OMDb error for Trolls: Request limit reached!
# OMDb error for Rush Hour 2: Request limit reached!
# OMDb error for I, Robot: Request limit reached!
# OMDb error for xXx: Return of Xander Cage: Request limit reached!
# OMDb error for Pocahontas: Request limit reached!
# OMDb error for How the Grinch Stole Christmas: Request limit reached!
# OMDb error for Star Trek Beyond: Request limit reached!
# OMDb error for Over the Hedge: Request limit reached!
# OMDb error for Alvin and the Chipmunks: Chipwrecked: Request limit reached!
# OMDb error for Wanted: Request limit reached!
# OMDb error for The Flintstones: Request limit reached!
# OMDb error for A Quiet Place: Request limit reached!
# OMDb error for Enchanted: Request limit reached!
# OMDb error for 300: Rise of an Empire: Request limit reached!
# OMDb error for Article 20: Request limit reached!
# OMDb error for The Hunger Games: The Ballad of Songbirds & Snakes: Request limit reached!
# OMDb error for Batman Forever: Request limit reached!
# OMDb error for Prince of Persia: The Sands of Time: Request limit reached!
# OMDb error for The Curious Case of Benjamin Button: Request limit reached!
# OMDb error for The Rock: Request limit reached!
# OMDb error for Now You See Me 2: Request limit reached!
# OMDb error for Sherlock Holmes: A Game of Shadows: Request limit reached!
# OMDb error for Never Say Die: Request limit reached!
# OMDb error for Lost in the Stars: Request limit reached!
# OMDb error for Fantastic Four: Request limit reached!
# OMDb error for Tomorrow Never Dies: Request limit reached!
# OMDb error for Indiana Jones and the Temple of Doom: Request limit reached!
# OMDb error for The Good Dinosaur: Request limit reached!
# OMDb error for Little Women: Request limit reached!
# OMDb error for Back to the Future Part II: Request limit reached!
# OMDb error for The Wild Robot: Request limit reached!
# OMDb error for The Great Wall: Request limit reached!
# OMDb error for Free Guy: Request limit reached!
# OMDb error for 22 Jump Street: Request limit reached!
# OMDb error for Meet the Parents: Request limit reached!
# OMDb error for Lost Ladies: Request limit reached!
# OMDb error for Who Framed Roger Rabbit: Request limit reached!
# OMDb error for Black Swan: Request limit reached!
# OMDb error for The Perfect Storm: Request limit reached!
# OMDb error for Crocodile Dundee: Request limit reached!
# OMDb error for Se7en: Request limit reached!
# OMDb error for John Wick: Chapter 3 - Parabellum: Request limit reached!
# OMDb error for The Devil Wears Prada: Request limit reached!
# OMDb error for Paddington: Request limit reached!
# OMDb error for Taken 3: Request limit reached!
# OMDb error for The Hunchback of Notre Dame: Request limit reached!
# OMDb error for A Christmas Carol: Request limit reached!
# OMDb error for The SpongeBob Movie: Sponge Out of Water: Request limit reached!
# OMDb error for Suzume: Request limit reached!
# OMDb error for The Conjuring 2: Request limit reached!
# OMDb error for Megamind: Request limit reached!
# OMDb error for Green Book: Request limit reached!
# OMDb error for Lethal Weapon 3: Request limit reached!
# OMDb error for The Ugly Truth: Request limit reached!
# OMDb error for Robin Hood: Request limit reached!
# OMDb error for Inglourious Basterds: Request limit reached!
# OMDb error for Schindler's List: Request limit reached!
# OMDb error for The Conjuring: Request limit reached!
# OMDb error for 101 Dalmatians: Request limit reached!
# OMDb error for Fatal Attraction: Request limit reached!
# OMDb error for Sonic the Hedgehog: Request limit reached!
# OMDb error for The Last Airbender: Request limit reached!
# OMDb error for The Polar Express: Request limit reached!
# OMDb error for The Proposal: Request limit reached!
# OMDb error for A Beautiful Mind: Request limit reached!
# OMDb error for Beverly Hills Cop: Request limit reached!
# OMDb error for Final Destination Bloodlines: Request limit reached!
# OMDb error for Air Force One: Request limit reached!
# OMDb error for Wonder: Request limit reached!
# OMDb error for The Expendables 2: Request limit reached!
# OMDb error for Chicken Little: Request limit reached!
# OMDb error for As Good as It Gets: Request limit reached!
# OMDb error for Knives Out: Request limit reached!
# OMDb error for Maze Runner: The Scorch Trials: Request limit reached!
# OMDb error for Resident Evil: The Final Chapter: Request limit reached!
# OMDb error for Austin Powers: The Spy Who Shagged Me: Request limit reached!
# OMDb error for The Lego Batman Movie: Request limit reached!
# OMDb error for Ocean's Thirteen: Request limit reached!
# OMDb error for Dangal: Request limit reached!
# OMDb error for Little Fockers: Request limit reached!
# OMDb error for Bolt: Request limit reached!
# OMDb error for Runaway Bride: Request limit reached!
# OMDb error for Ransom: Request limit reached!
# OMDb error for The Blind Side: Request limit reached!
# OMDb error for The Fault in Our Stars: Request limit reached!
# OMDb error for The Pursuit of Happyness: Request limit reached!
# OMDb error for Rise of the Guardians: Request limit reached!
# OMDb error for Close Encounters of the Third Kind: Request limit reached!
# OMDb error for Chicago: Request limit reached!
# OMDb error for Annabelle: Creation: Request limit reached!
# OMDb error for Skyscraper: Request limit reached!
# OMDb error for A Good Day to Die Hard: Request limit reached!
# OMDb error for Mulan: Request limit reached!
# OMDb error for Passengers: Request limit reached!
# OMDb error for Battleship: Request limit reached!
# OMDb error for One Hundred and One Dalmatians: Request limit reached!
# OMDb error for Liar Liar: Request limit reached!
# OMDb error for G.I. Joe: The Rise of Cobra: Request limit reached!
# OMDb error for Wrath of the Titans: Request limit reached!
# OMDb error for Fantastic Four: Rise of the Silver Surfer: Request limit reached!
# OMDb error for Hook: Request limit reached!
# OMDb error for Superman: Request limit reached!
# OMDb error for Rocky IV: Request limit reached!
# OMDb error for Rambo: First Blood Part II: Request limit reached!
# OMDb error for Van Helsing: Request limit reached!
# OMDb error for Resident Evil: Afterlife: Request limit reached!
# OMDb error for Stuart Little: Request limit reached!
# OMDb error for Beverly Hills Cop II: Request limit reached!
# OMDb error for Alice Through the Looking Glass: Request limit reached!
# OMDb error for Real Steel: Request limit reached!
# OMDb error for My Best Friend's Wedding: Request limit reached!
# OMDb error for Migration: Request limit reached!
# OMDb error for Horton Hears a Who!: Request limit reached!
# OMDb error for Ocean's Eight: Request limit reached!
# OMDb error for A Quiet Place Part II: Request limit reached!
# OMDb error for Five Nights at Freddy's: Request limit reached!
# OMDb error for Insurgent: Request limit reached!
# OMDb error for Look Who's Talking: Request limit reached!
# OMDb error for Austin Powers in Goldmember: Request limit reached!
# OMDb error for Ghostbusters: Request limit reached!
# OMDb error for Miss Peregrine's Home for Peculiar Children: Request limit reached!
# OMDb error for X-Men: Request limit reached!
# OMDb error for Ferdinand: Request limit reached!
# OMDb error for Shutter Island: Request limit reached!
# OMDb error for Doctor Dolittle: Request limit reached!
# OMDb error for The Boy and the Heron: Request limit reached!
# OMDb error for Salt: Request limit reached!
# OMDb error for G-Force: Request limit reached!
# OMDb error for The Departed: Request limit reached!
# OMDb error for What Lies Beneath: Request limit reached!
# OMDb error for Sex and the City 2: Request limit reached!
# OMDb error for Paddington 2: Request limit reached!
# OMDb error for Pacific Rim: Uprising: Request limit reached!
# OMDb error for Shakespeare in Love: Request limit reached!
# OMDb error for Divergent: Request limit reached!
# OMDb error for Coming to America: Request limit reached!
# OMDb error for Elvis: Request limit reached!
# OMDb error for The Bourne Supremacy: Request limit reached!
# OMDb error for Wedding Crashers: Request limit reached!
# OMDb error for Bridesmaids: Request limit reached!
# OMDb error for Maze Runner: The Death Cure: Request limit reached!
# OMDb error for Casper: Request limit reached!
# OMDb error for Bee Movie: Request limit reached!
# OMDb error for American Pie 2: Request limit reached!
# OMDb error for Pitch Perfect 2: Request limit reached!
# OMDb error for The Green Mile: Request limit reached!
# OMDb error for The Sound of Music: Request limit reached!
# OMDb error for Oblivion: Request limit reached!
# OMDb error for Elysium: Request limit reached!
# OMDb error for Lethal Weapon 4: Request limit reached!
# OMDb error for John Carter: Request limit reached!
# OMDb error for Turbo: Request limit reached!
# OMDb error for Bridget Jones's Diary: Request limit reached!
# OMDb error for Bāhubali 2: The Conclusion: Request limit reached!
# OMDb error for Batman Returns: Request limit reached!
# OMDb error for The Tourist: Request limit reached!
# OMDb error for Split: Request limit reached!
# OMDb error for Mojin: The Lost Legend: Request limit reached!
# OMDb error for Scary Movie: Request limit reached!
# OMDb error for xXx: Request limit reached!
# OMDb error for The Bourne Legacy: Request limit reached!
# OMDb error for Boonie Bears: Time Twist: Request limit reached!
# OMDb error for Scooby-Doo: Request limit reached!
# OMDb error for Creed III: Request limit reached!
# OMDb error for Lincoln: Request limit reached!
# OMDb error for Spirited Away: Request limit reached!
# OMDb error for Lara Croft: Tomb Raider: Request limit reached!
# OMDb error for Tomb Raider: Request limit reached!
# OMDb error for The Expendables: Request limit reached!
# OMDb error for Jerry Maguire: Request limit reached!
# OMDb error for Bad Boys II: Request limit reached!
# OMDb error for Lilo & Stitch: Request limit reached!
# OMDb error for Mr. Peabody & Sherman: Request limit reached!
# OMDb error for The Silence of the Lambs: Request limit reached!
# OMDb error for Grown Ups: Request limit reached!
# OMDb error for The Flash: Request limit reached!
# OMDb error for The Princess and the Frog: Request limit reached!
# OMDb error for Neighbors: Request limit reached!
# OMDb error for The Firm: Request limit reached!
# OMDb error for We're the Millers: Request limit reached!
# OMDb error for Gran Torino: Request limit reached!
# OMDb error for Something's Gotta Give: Request limit reached!
# OMDb error for Rocky III: Request limit reached!
# OMDb error for 10,000 BC: Request limit reached!
# OMDb error for American Gangster: Request limit reached!
# OMDb error for The Nun II: Request limit reached!
# OMDb error for Epic: Request limit reached!
# OMDb error for Exodus: Gods and Kings: Request limit reached!
# OMDb error for Bambi: Request limit reached!
# OMDb error for Indecent Proposal: Request limit reached!
# OMDb error for Weapons: Request limit reached!
# OMDb error for Bridget Jones: The Edge of Reason: Request limit reached!
# OMDb error for The Incredible Hulk: Request limit reached!
# OMDb error for Waterworld: Request limit reached!
# OMDb error for The Truman Show: Request limit reached!
# OMDb error for Charlie's Angels: Request limit reached!
# OMDb error for The Fifth Element: Request limit reached!
# OMDb error for Cinderella: Request limit reached!
# OMDb error for Jumanji: Request limit reached!
# OMDb error for Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan: Request limit reached!
# OMDb error for Robots: Request limit reached!
# OMDb error for Knight and Day: Request limit reached!
# OMDb error for A Quiet Place: Day One: Request limit reached!
# OMDb error for TAYLOR SWIFT | THE ERAS TOUR: Request limit reached!
# OMDb error for Total Recall: Request limit reached!
# OMDb error for Encanto: Request limit reached!
# OMDb error for This Is It: Request limit reached!
# OMDb error for Terminator: Dark Fate: Request limit reached!
# OMDb error for The Lone Ranger: Request limit reached!
# OMDb error for Super 8: Request limit reached!
# OMDb error for Halloween: Request limit reached!
# OMDb error for Blade Runner 2049: Request limit reached!
# OMDb error for Charlie's Angels: Full Throttle: Request limit reached!
# OMDb error for The Dollars Are Coming!: Request limit reached!
# OMDb error for Rush Hour 3: Request limit reached!
# OMDb error for The First Slam Dunk: Request limit reached!
# OMDb error for The Full Monty: Request limit reached!
# OMDb error for Parasite: Request limit reached!
# OMDb error for Annabelle: Request limit reached!
# OMDb error for The Village: Request limit reached!
# OMDb error for Erin Brockovich: Request limit reached!
# OMDb error for Us: Request limit reached!
# OMDb error for Marley & Me: Request limit reached!
# OMDb error for Get Out: Request limit reached!
# OMDb error for Cliffhanger: Request limit reached!
# OMDb error for Wish: Request limit reached!
# OMDb error for The Garfield Movie: Request limit reached!
# OMDb error for Kung Fu Yoga: Request limit reached!
# OMDb error for Babe: Request limit reached!
# OMDb error for Men in Black: International: Request limit reached!
# OMDb error for Lighting Up the Stars: Request limit reached!
# OMDb error for Wild Hogs: Request limit reached!
# OMDb error for High School Musical 3: Senior Year: Request limit reached!
# OMDb error for Hercules: Request limit reached!
# OMDb error for Chang'an: Request limit reached!
# OMDb error for Dark Phoenix: Request limit reached!
# OMDb error for True Grit: Request limit reached!
# OMDb error for Dolittle: Request limit reached!
# OMDb error for Bean: Request limit reached!
# OMDb error for American Hustle: Request limit reached!
# OMDb error for You've Got Mail: Request limit reached!
# OMDb error for Love Actually: Request limit reached!
# OMDb error for Enemy of the State: Request limit reached!
# OMDb error for Sound of Freedom: Request limit reached!
# OMDb error for Eragon: Request limit reached!
# OMDb error for Brother Bear: Request limit reached!
# OMDb error for The Mask of Zorro: Request limit reached!
# OMDb error for Space Jam: Request limit reached!
# OMDb error for The Bad Guys: Request limit reached!
# OMDb error for Red Cliff: Request limit reached!
# OMDb error for Nidja's Kitchen 2: Request limit reached!
# OMDb error for The Ring: Request limit reached!
# OMDb error for Journey to the West: The Demons Strike Back: Request limit reached!
# OMDb error for The Blair Witch Project: Request limit reached!
# OMDb error for Cloudy with a Chance of Meatballs 2: Request limit reached!
# OMDb error for Unbreakable: Request limit reached!
# OMDb error for Dumb and Dumber: Request limit reached!
# OMDb error for Grown Ups 2: Request limit reached!
# OMDb error for Glass: Request limit reached!
# OMDb error for The Peanuts Movie: Request limit reached!
# OMDb error for Four Weddings and a Funeral: Request limit reached!
# OMDb error for Rango: Request limit reached!
# OMDb error for Face/Off: Request limit reached!
# OMDb error for Teenage Mutant Ninja Turtles: Out of the Shadows: Request limit reached!
# OMDb error for Dark Shadows: Request limit reached!
# OMDb error for Hulk: Request limit reached!
# OMDb error for The Bravest: Request limit reached!
# OMDb error for Welcome to the Sticks: Request limit reached!
# OMDb error for The Godfather: Request limit reached!
# OMDb error for Pixels: Request limit reached!
# OMDb error for Hercules: Request limit reached!
# OMDb error for Rush Hour: Request limit reached!
# OMDb error for Back to the Future Part III: Request limit reached!
# OMDb error for After Earth: Request limit reached!
# OMDb error for A Few Good Men: Request limit reached!
# OMDb error for Cloudy with a Chance of Meatballs: Request limit reached!
# OMDb error for 8 Mile: Request limit reached!
# OMDb error for Daddy's Home: Request limit reached!
# OMDb error for 3 Men and a Baby: Request limit reached!
# OMDb error for RoboCop: Request limit reached!
# OMDb error for Eraser: Request limit reached!
# OMDb error for Alien: Covenant: Request limit reached!
# OMDb error for Sully: Request limit reached!
# OMDb error for Assassin's Creed: Request limit reached!
# OMDb error for Click: Request limit reached!
# OMDb error for Jiang Ziya: Request limit reached!
# OMDb error for Resident Evil: Retribution: Request limit reached!
# OMDb error for Die Hard 2: Request limit reached!
# OMDb error for Crocodile Dundee II: Request limit reached!
# OMDb error for Bullet Train: Request limit reached!
# OMDb error for Ip Man 4: The Finale: Request limit reached!
# OMDb error for Crazy Rich Asians: Request limit reached!
# OMDb error for Batman & Robin: Request limit reached!
# OMDb error for Gulliver's Travels: Request limit reached!
# OMDb error for Gone in Sixty Seconds: Request limit reached!
# OMDb error for Saturday Night Fever: Request limit reached!
# OMDb error for Silver Linings Playbook: Request limit reached!
# OMDb error for 2 Fast 2 Furious: Request limit reached!
# OMDb error for Home Coming: Request limit reached!
# OMDb error for Howl's Moving Castle: Request limit reached!
# OMDb error for Hidden Figures: Request limit reached!
# OMDb error for A.I. Artificial Intelligence: Request limit reached!
# OMDb error for Dead Poets Society: Request limit reached!
# OMDb error for Spy: Request limit reached!
# OMDb error for American Pie: Request limit reached!
# OMDb error for American Reunion: Request limit reached!
# OMDb error for Big Daddy: Request limit reached!
# OMDb error for Alvin and the Chipmunks: The Road Chip: Request limit reached!
# OMDb error for The Imitation Game: Request limit reached!
# OMDb error for Cruella: Request limit reached!
# OMDb error for The Day the Earth Stood Still: Request limit reached!
# OMDb error for The Girl with the Dragon Tattoo: Request limit reached!
# OMDb error for Juno: Request limit reached!
# OMDb error for Argo: Request limit reached!
# OMDb error for Mr. Bean's Holiday: Request limit reached!
# OMDb error for The English Patient: Request limit reached!
# OMDb error for Sister Act: Request limit reached!
# OMDb error for American Wedding: Request limit reached!
# OMDb error for Annabelle Comes Home: Request limit reached!
# OMDb error for Constantine: Request limit reached!
# OMDb error for Get Smart: Request limit reached!
# OMDb error for Life Is Beautiful: Request limit reached!
# OMDb error for The Black Hand: Request limit reached!
# OMDb error for The Heat: Request limit reached!
# OMDb error for Ghostbusters: Request limit reached!
# OMDb error for Ghost Rider: Request limit reached!
# OMDb error for Goodbye Mr. Loser: Request limit reached!
# OMDb error for Elf: Request limit reached!
# OMDb error for Lethal Weapon 2: Request limit reached!
# OMDb error for The Green Hornet: Request limit reached!
# OMDb error for Sleepless in Seattle: Request limit reached!
# OMDb error for Out of Africa: Request limit reached!
# OMDb error for Baby Driver: Request limit reached!
# OMDb error for Immortals: Request limit reached!
# OMDb error for Taken: Request limit reached!
# OMDb error for Percy Jackson & the Olympians: The Lightning Thief: Request limit reached!
# OMDb error for Lightyear: Request limit reached!
# OMDb error for Shock Wave 2: Request limit reached!
# OMDb error for Hansel & Gretel: Witch Hunters: Request limit reached!
# OMDb error for Valerian and the City of a Thousand Planets: Request limit reached!
# OMDb error for Good Will Hunting: Request limit reached!
# OMDb error for Better Days: Request limit reached!
# OMDb error for Ford v Ferrari: Request limit reached!
# OMDb error for Rocky: Request limit reached!
# OMDb error for The Social Network: Request limit reached!
# OMDb error for Chicken Run: Request limit reached!
# OMDb error for The Bad Guys 2: Request limit reached!
# OMDb error for Youth: Request limit reached!
# OMDb error for Con Air: Request limit reached!
# OMDb error for Interview with the Vampire: Request limit reached!
# OMDb error for Flightplan: Request limit reached!
# OMDb error for Yes Man: Request limit reached!
# OMDb error for Non-Stop: Request limit reached!
# OMDb error for Honey, I Shrunk the Kids: Request limit reached!
# OMDb error for Fahrenheit 9/11: Request limit reached!
# OMDb error for Jumper: Request limit reached!
# OMDb error for Wild Wild West: Request limit reached!
# OMDb error for Boonie Bears: Guardian Code: Request limit reached!
# OMDb error for Geostorm: Request limit reached!
# OMDb error for Presumed Innocent: Request limit reached!
# OMDb error for Jungle Cruise: Request limit reached!
# OMDb error for Scary Movie 3: Request limit reached!
# OMDb error for Napoleon: Request limit reached!
# OMDb error for Collateral: Request limit reached!
# OMDb error for Inferno: Request limit reached!
# OMDb error for Knocked Up: Request limit reached!
# OMDb error for Green Lantern: Request limit reached!
# OMDb error for Planes: Request limit reached!
# OMDb error for The Terminal: Request limit reached!
# OMDb error for What Happens in Vegas: Request limit reached!
# OMDb error for It's Complicated: Request limit reached!
# OMDb error for Pushpa 2 - The Rule: Request limit reached!
# OMDb error for Captain Phillips: Request limit reached!
# OMDb error for The Prince of Egypt: Request limit reached!
# OMDb error for Kingdom of Heaven: Request limit reached!
# OMDb error for Jack Reacher: Request limit reached!
# OMDb error for Smile: Request limit reached!
# OMDb error for Dracula Untold: Request limit reached!
# OMDb error for Central Intelligence: Request limit reached!
# OMDb error for The Emoji Movie: Request limit reached!
# OMDb error for Million Dollar Baby: Request limit reached!
# OMDb error for Twins: Request limit reached!
# OMDb error for The Help: Request limit reached!
# OMDb error for Valentine's Day: Request limit reached!
# OMDb error for Superman II: Request limit reached!
# OMDb error for Bad Teacher: Request limit reached!
# OMDb error for A Little Red Flower: Request limit reached!
# OMDb error for The Croods: A New Age: Request limit reached!
# OMDb error for Clear and Present Danger: Request limit reached!
# OMDb error for Ted 2: Request limit reached!
# OMDb error for Bram Stoker's Dracula: Request limit reached!
# OMDb error for Vertical Limit: Request limit reached!
# OMDb error for Journey to the West: Conquering the Demons: Request limit reached!
# OMDb error for Ghostbusters II: Request limit reached!
# OMDb error for Nobody: Request limit reached!
# OMDb error for The Sorcerer's Apprentice: Request limit reached!
# OMDb error for The Patriot: Request limit reached!
# OMDb error for Just Go with It: Request limit reached!
# OMDb error for Anyone But You: Request limit reached!
# OMDb error for The Expendables 3: Request limit reached!
# OMDb error for Dirty Dancing: Request limit reached!
# OMDb error for Creed II: Request limit reached!
# OMDb error for Smallfoot: Request limit reached!
# OMDb error for Public Enemies: Request limit reached!
# OMDb error for The Bourne Identity: Request limit reached!
# OMDb error for Disclosure: Request limit reached!
# OMDb error for Crouching Tiger, Hidden Dragon: Request limit reached!
# OMDb error for Pulp Fiction: Request limit reached!
# OMDb error for The Aviator: Request limit reached!
# OMDb error for Braveheart: Request limit reached!
# OMDb error for Into the Woods: Request limit reached!
# OMDb error for Bedtime Stories: Request limit reached!
# OMDb error for Entrapment: Request limit reached!
# OMDb error for Ace Ventura: When Nature Calls: Request limit reached!
# OMDb error for End of Days: Request limit reached!
# OMDb error for Miss Congeniality: Request limit reached!
# OMDb error for Bridget Jones's Baby: Request limit reached!
# OMDb error for Fury: Request limit reached!
# OMDb error for Battle: Los Angeles: Request limit reached!
# OMDb error for Due Date: Request limit reached!
# OMDb error for Australia: Request limit reached!
# OMDb error for Master and Commander: The Far Side of the World: Request limit reached!
# OMDb error for The Little Mermaid: Request limit reached!
# OMDb error for Nice View: Request limit reached!
# OMDb error for District 9: Request limit reached!
# OMDb error for Moonraker: Request limit reached!
# OMDb error for The Others: Request limit reached!
# OMDb error for Horrible Bosses: Request limit reached!
# OMDb error for Trolls Band Together: Request limit reached!
# OMDb error for Now You See Me: Now You Don't: Request limit reached!
# OMDb error for Us and Them: Request limit reached!
# OMDb error for Tomorrowland: Request limit reached!
# OMDb error for Red Dragon: Request limit reached!
# OMDb error for Lemony Snicket's A Series of Unfortunate Events: Request limit reached!
# OMDb error for Dungeons & Dragons: Honor Among Thieves: Request limit reached!
# OMDb error for Safe House: Request limit reached!
# OMDb error for Lost in Thailand: Request limit reached!
# OMDb error for Me Before You: Request limit reached!
# OMDb error for S.W.A.T.: Request limit reached!
# OMDb error for Joker: Folie à Deux: Request limit reached!
# OMDb error for Traffic: Request limit reached!
# OMDb error for The Fast and the Furious: Request limit reached!
# OMDb error for Paranormal Activity 3: Request limit reached!
# OMDb error for Philadelphia: Request limit reached!
# OMDb error for The Conjuring: The Devil Made Me Do It: Request limit reached!
# OMDb error for The Marvels: Request limit reached!
# OMDb error for Sleepy Hollow: Request limit reached!
# OMDb error for London Has Fallen: Request limit reached!
# OMDb error for The Break-Up: Request limit reached!
# OMDb error for Snow White: Request limit reached!
# OMDb error for Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn): Request limit reached!
# OMDb error for JFK: Request limit reached!
# OMDb error for White House Down: Request limit reached!
# OMDb error for The Holiday: Request limit reached!
# OMDb error for Raging Fire: Request limit reached!
# OMDb error for A Dog's Purpose: Request limit reached!
# OMDb error for Eat Pray Love: Request limit reached!
# OMDb error for Ghostbusters: Afterlife: Request limit reached!
# OMDb error for The Addams Family: Request limit reached!
# OMDb error for You Don't Mess with the Zohan: Request limit reached!
# OMDb error for King Arthur: Request limit reached!
# OMDb error for Yogi Bear: Request limit reached!
# OMDb error for Everest: Request limit reached!
# OMDb error for Vanilla Sky: Request limit reached!
# OMDb error for Arrival: Request limit reached!
# OMDb error for Need for Speed: Request limit reached!
# OMDb error for DC League of Super-Pets: Request limit reached!
# OMDb error for One Battle After Another: Request limit reached!
# OMDb error for Ponyo: Request limit reached!
# OMDb error for Patch Adams: Request limit reached!
# OMDb error for PAW Patrol: The Mighty Movie: Request limit reached!
# OMDb error for Fun with Dick and Jane: Request limit reached!
# OMDb error for Ghostbusters: Frozen Empire: Request limit reached!
# OMDb error for Teenage Mutant Ninja Turtles: Request limit reached!
# OMDb error for Kindergarten Cop: Request limit reached!
# OMDb error for Straight Outta Compton: Request limit reached!
# OMDb error for 21 Jump Street: Request limit reached!
# OMDb error for Flashdance: Request limit reached!
# OMDb error for DeAD: Request limit reached!
# OMDb error for Garfield: Request limit reached!
# OMDb error for Cats & Dogs: Request limit reached!
# OMDb error for The Hunt for Red October: Request limit reached!
# OMDb error for Valkyrie: Request limit reached!
# OMDb error for Jigsaw Prank Gone Wrong: Request limit reached!
# OMDb error for Seeds of Destiny: Request limit reached!
# OMDb error for The Gods Must Be Crazy: Request limit reached!
# OMDb error for Percy Jackson: Sea of Monsters: Request limit reached!
# OMDb error for The Lego Movie 2: The Second Part: Request limit reached!
# OMDb error for Two Weeks Notice: Request limit reached!
# OMDb error for RED: Request limit reached!
# OMDb error for Total Recall: Request limit reached!
# OMDb error for City of Angels: Request limit reached!
# OMDb error for The Pacifier: Request limit reached!
# OMDb error for The Impossible: Request limit reached!
# OMDb error for Christopher Robin: Request limit reached!
# OMDb error for Jack the Giant Slayer: Request limit reached!
# OMDb error for Open Season: Request limit reached!
# OMDb error for Smurfs: The Lost Village: Request limit reached!
# OMDb error for Spy Kids 3-D: Game Over: Request limit reached!
# OMDb error for Panic Room: Request limit reached!
# OMDb error for The Other Woman: Request limit reached!
# OMDb error for Stargate: Request limit reached!
# OMDb error for 50 First Dates: Request limit reached!
# OMDb error for The Vow: Request limit reached!
# OMDb error for Jujutsu Kaisen 0: Request limit reached!
# OMDb error for Anger Management: Request limit reached!
# OMDb error for Beowulf: Request limit reached!
# OMDb error for Tropic Thunder: Request limit reached!
# Fact table saved to movie_fact_table.csv
#                       Title  Year  TMDB_ID  \
# 0                    Avatar  2009    19995
# 1         Avengers: Endgame  2019   299534
# 2  Avatar: The Way of Water  2022    76600
# 3                   Titanic  1997      597
# 4                  Ne Zha 2  2025   980477
#
#                                          Genre       Director  \
# 0  Action, Adventure, Fantasy, Science Fiction  James Cameron
# 1           Adventure, Science Fiction, Action  Anthony Russo
# 2           Action, Adventure, Science Fiction  James Cameron
# 3                               Drama, Romance  James Cameron
# 4        Animation, Fantasy, Adventure, Action        Jiao Zi
#
#                                               Actors Release_Date  Runtime  \
# 0  Sam Worthington, Zoe Saldaña, Sigourney Weaver...   2009-12-15      162
# 1  Robert Downey Jr., Chris Evans, Mark Ruffalo, ...   2019-04-24      181
# 2  Sam Worthington, Zoe Saldaña, Sigourney Weaver...   2022-12-14      192
# 3  Leonardo DiCaprio, Kate Winslet, Billy Zane, K...   1997-11-18      194
# 4        Lu Yanting, Joseph, Han Mo, Chen Hao, Lu Qi   2025-01-29      144
#
#    Budget  Worldwide_Gross  Vote_Average IMDB_Rating Votes
# 0   237.0      2923.706026         7.594         N/A   N/A
# 1   356.0      2799.439100         8.237         N/A   N/A
# 2   350.0      2353.096253         7.609         N/A   N/A
# 3   200.0      2264.162353         7.903         N/A   N/A
# 4    80.0      2150.000000         8.068         N/A   N/A

# %%
fact_table.head()
# Out:
#                       Title  Year  TMDB_ID  \
# 0                    Avatar  2009    19995
# 1         Avengers: Endgame  2019   299534
# 2  Avatar: The Way of Water  2022    76600
# 3                   Titanic  1997      597
# 4                  Ne Zha 2  2025   980477
#
#                                          Genre       Director  \
# 0  Action, Adventure, Fantasy, Science Fiction  James Cameron
# 1           Adventure, Science Fiction, Action  Anthony Russo
# 2           Action, Adventure, Science Fiction  James Cameron
# 3                               Drama, Romance  James Cameron
# 4        Animation, Fantasy, Adventure, Action        Jiao Zi
#
#                                               Actors Release_Date  Runtime  \
# 0  Sam Worthington, Zoe Saldaña, Sigourney Weaver...   2009-12-15      162
# 1  Robert Downey Jr., Chris Evans, Mark Ruffalo, ...   2019-04-24      181
# 2  Sam Worthington, Zoe Saldaña, Sigourney Weaver...   2022-12-14      192
# 3  Leonardo DiCaprio, Kate Winslet, Billy Zane, K...   1997-11-18      194
# 4        Lu Yanting, Joseph, Han Mo, Chen Hao, Lu Qi   2025-01-29      144
#
#    Budget  Worldwide_Gross  Vote_Average IMDB_Rating Votes
# 0   237.0      2923.706026         7.594         N/A   N/A
# 1   356.0      2799.439100         8.237         N/A   N/A
# 2   350.0      2353.096253         7.609         N/A   N/A
# 3   200.0      2264.162353         7.903         N/A   N/A
# 4    80.0      2150.000000         8.068         N/A   N/A

# %%
fact_table.shape
# Out:
# (1000, 13)

# %%
from google.colab import files
files.download('movie_fact_table.csv')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import sklearn

# %%
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

# Part 1a: Loading and Cleaning Data
def load_and_clean_data(file_path):
    """
    Load the CSV and clean relevant columns.
    - Converts strings to numbers where possible.
    - Handles dates to extract month.
    """
    df = pd.read_csv(file_path)
    df['Year'] = pd.to_numeric(df['Year'], errors='coerce')  # Convert to number, ignore errors
    df['Runtime'] = pd.to_numeric(df['Runtime'], errors='coerce')
    df['Budget'] = pd.to_numeric(df['Budget'], errors='coerce')
    df['Worldwide_Gross'] = pd.to_numeric(df['Worldwide_Gross'], errors='coerce')
    df['Release_Date'] = pd.to_datetime(df['Release_Date'], errors='coerce')  # Convert to date
    df['Release_Month'] = df['Release_Date'].dt.month.fillna(0)  # Get month, fill missing with 0
    return df

# Part 1b: Engineering Features
def engineer_features(df):
    """
    Engineer features like genre encoding, director encoding, and num_actors.
    - Splits genres into lists and encodes them.
    - Encodes top directors.
    - Counts number of actors.
    Returns features, target, mlb (genre encoder), and top_directors.
    """
    # Handling genres: Split comma-separated into lists
    df['Genre_List'] = df['Genre'].apply(lambda x: [g.strip() for g in str(x).split(',')] if pd.notnull(x) else [])

    # Multi-label encode genres (turns genres into binary columns, e.g., Action: 1 or 0)
    mlb = MultiLabelBinarizer()
    genre_encoded = pd.DataFrame(mlb.fit_transform(df['Genre_List']), columns=mlb.classes_, index=df.index)

    # Director: One-hot encode top 10, group others (turns directors into binary columns)
    top_directors = df['Director'].value_counts().nlargest(10).index
    df['Director'] = df['Director'].apply(lambda x: x if x in top_directors else 'Other')
    director_encoded = pd.get_dummies(df['Director'], prefix='Director')

    # Num_Actors: Count from Actors column
    df['Num_Actors'] = df['Actors'].apply(lambda x: len(str(x).split(',')) if pd.notnull(x) else 0)

    # Combine all features into one DataFrame
    features = pd.concat([df[['Year', 'Runtime', 'Budget', 'Release_Month', 'Num_Actors']], genre_encoded, director_encoded], axis=1)
    target = df['Worldwide_Gross']

    # Drop rows with missing target or budget (key feature)
    valid_idx = target.notnull() & features['Budget'].notnull()
    features = features[valid_idx].fillna(features.median(numeric_only=True))  # Fill missing numbers with medians
    target = target[valid_idx]

    return features, target, mlb, top_directors

# %%
from sklearn.metrics import r2_score
from sklearn.model_selection import KFold, cross_val_score

# Part 2a: Training Model
def train_model(X_train, y_train):
    """
    Train the Random Forest model.
    - n_estimators=100: Builds 100 trees.
    - random_state=42: For reproducible results.
    """
    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)  # Fit the model to training data
    return model

# Part 2b: Evaluating the Model
def evaluate_model(model, X_test, y_test):
    """
    Evaluate the model on test data.
    - Predicts on test set.
    - Computes R² score (how well the model explains variance; 1 is perfect).
    """
    y_pred = model.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    print("Test R²:", r2)
    return r2

# Part 2c: Evaluate with K-Fold Cross-Validation
def evaluate_model_with_kfold(X, y, n_estimators=100, k=5):
    """
    Evaluate the model using K-Fold Cross-Validation.
    - Uses KFold to split data into k folds.
    - Trains and evaluates the Random Forest model k times.
    - Computes average R² across folds.
    """
    model = RandomForestRegressor(n_estimators=n_estimators, random_state=42)
    kfold = KFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(model, X, y, cv=kfold, scoring='r2')
    print("R² scores for each fold:", scores)
    print("Average R²:", scores.mean())
    print("Standard Deviation of R²:", scores.std())
    return scores.mean()

# %%
# Part 3: Preparing New Movie Input
def prepare_new_movie_input(movie_details, mlb, top_directors, training_columns):
    """
    Prepare features for a new movie.
    - Uses the same encoding as training.

    Args:
        movie_details (dict): Dictionary with movie data.
        mlb: MultiLabelBinarizer from training.
        top_directors: List of top directors from training.
        training_columns (list): List of feature columns from training.

    Returns:
        pd.DataFrame: Prepared features.
    """
    input_df = pd.DataFrame([movie_details])

    # Genre encoding (using mlb from training)
    genre_encoded = pd.DataFrame(mlb.transform([movie_details['Genre_List']]), columns=mlb.classes_)

    # Director encoding
    input_df['Director'] = input_df['Director'].apply(lambda x: x if x in top_directors else 'Other')
    director_encoded = pd.get_dummies(input_df['Director'], prefix='Director')

    # Combine features
    all_features = pd.concat([input_df[['Year', 'Runtime', 'Budget', 'Release_Month', 'Num_Actors']], genre_encoded, director_encoded], axis=1)

    # Reindex to match training columns, fill missing with 0 (e.g., unseen genres/directors get 0)
    all_features = all_features.reindex(columns=training_columns, fill_value=0)

    return all_features

# %%
# Part 4: Predicting Revenue
def predict_revenue(model, input_features):
    """
    Predict revenue using the trained model.
    """
    prediction = model.predict(input_features)[0]  # Get the first (only) prediction
    return prediction

# %%
# Run Everything Sequentially
# Load and prepare data
df = load_and_clean_data('movie_fact_table.csv')
features, target, mlb, top_directors = engineer_features(df)

# Get training columns for later use
training_columns = features.columns.tolist()

# Split data for training
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.4, random_state=42)

# Train and evaluate
model = train_model(X_train, y_train)
evaluate_model(model, X_test, y_test)

# Movie details for Avatar: Fire and Ash
movie_details = {
    'Year': 2025,
    'Runtime': 195,
    'Budget': 400,
    'Release_Month': 12,
    'Num_Actors': 5,
    'Genre_List': ['Action', 'Adventure', 'Fantasy', 'Science Fiction'],
    'Director': 'James Cameron'
}

# Prepare input
all_features = prepare_new_movie_input(movie_details, mlb, top_directors, training_columns)

# Predict
prediction = predict_revenue(model, all_features)
print("Predicted Worldwide Gross: ${:.3f} billion".format(prediction / 1000))  # Format in billions
# Out:
# Test R²: 0.37052691736567367
# Predicted Worldwide Gross: $1.930 billion
